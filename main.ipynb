# %%
import os
import requests

pdf="Andrew S. tanenbaum - Modern Operating Systems.pdf"
if not os.path.exists(pdf):
    url = input("Enter the URL to download the PDF: ")
    if not url:
        print("No URL provided. Exiting.")
        exit(1)
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to download the PDF. Status code: {response.status_code}")
        print("Exiting.")
        exit(1)
    with open(pdf, 'wb') as file:
        file.write(response.content)
    print(f"{pdf} has been downloaded successfully.")
else:
    print(f"{pdf} already exists. Skipping download.")
# Out:
# Andrew S. tanenbaum - Modern Operating Systems.pdf already exists. Skipping download.

# %%
import pymupdf
from tqdm.auto import tqdm
doc = pymupdf.open(pdf)
page_and_text=[]
def text_format(text):
    text = text.replace('\n', ' ').strip()
    return text
for pagenumber,text in tqdm(enumerate(doc), total=len(doc), desc="Processing pages"):
    text=text.get_text()
    text = text_format(text)
    if not text:
        continue
    page_and_text.append({"page": pagenumber + 1, "total char": len(text), "text": text,"total words": len(text.split()), "total lines without nlp": len(text.split('.')),"tokens":len(text)//4})
print(f"Total pages processed: {len(page_and_text)}")
with open("page_and_text.json", "w") as f:
    import json
    json.dump(page_and_text, f, indent=4)
# Out:
# Processing pages: 100%|██████████| 1137/1137 [00:01<00:00, 829.99it/s]
# Total pages processed: 1136

# %%
import pandas as pd
df =pd.DataFrame(page_and_text)
df.describe()
# Out:
#               page   total char  total words  total lines without nlp  \
# count  1136.000000  1136.000000  1136.000000              1136.000000
# mean    569.500000  2577.054577   440.107394                30.855634
# std     328.079259   637.874562   113.262398                17.773274
# min       2.000000     5.000000     1.000000                 1.000000
# 25%     285.750000  2245.000000   382.000000                24.000000
# 50%     569.500000  2711.500000   462.500000                29.000000
# 75%     853.250000  3068.000000   523.000000                34.000000
# max    1137.000000  3781.000000   634.000000               146.000000
#
#             tokens
# count  1136.000000
# mean    643.895246
# std     159.471717
# min       1.000000
# 25%     560.750000
# 50%     677.500000
# 75%     767.000000
# max     945.000000

# %%
from spacy.lang.en import English
nlp = English()
nlp.add_pipe("sentencizer")
for item in tqdm(page_and_text, desc="Processing sentences"):
    item["sentences"] = list(nlp(item["text"]).sents)
    item["sentences"] = [str(sentence) for sentence in item["sentences"]]
    item["total sentences"] = len(item["sentences"])
# Out:
# Processing sentences: 100%|██████████| 1136/1136 [00:01<00:00, 696.30it/s]

# %%
df= pd.DataFrame(page_and_text)
df.describe()
# Out:
#               page   total char  total words  total lines without nlp  \
# count  1136.000000  1136.000000  1136.000000              1136.000000
# mean    569.500000  2577.054577   440.107394                30.855634
# std     328.079259   637.874562   113.262398                17.773274
# min       2.000000     5.000000     1.000000                 1.000000
# 25%     285.750000  2245.000000   382.000000                24.000000
# 50%     569.500000  2711.500000   462.500000                29.000000
# 75%     853.250000  3068.000000   523.000000                34.000000
# max    1137.000000  3781.000000   634.000000               146.000000
#
#             tokens  total sentences
# count  1136.000000      1136.000000
# mean    643.895246        25.816021
# std     159.471717        10.516467
# min       1.000000         1.000000
# 25%     560.750000        21.000000
# 50%     677.500000        26.000000
# 75%     767.000000        31.000000
# max     945.000000        69.000000

# %%
def split_list(input_list: list,slice_size: int=5):
    return [input_list[i:i+slice_size] for i in range(0,len(input_list),slice_size)]
for i in tqdm(page_and_text, desc="Splitting sentences into chunks"):
    i["sentence_chunks"] = split_list(i["sentences"],10)
    i["num_chunk"]=len(i["sentence_chunks"])
with open("page_and_text_with_sentences.json", "w") as f:
    json.dump(page_and_text, f, indent=4)
# Out:
# Splitting sentences into chunks: 100%|██████████| 1136/1136 [00:00<00:00, 282253.97it/s]

# %%
import random
random.sample(page_and_text, 1)
# Out:
# [{'page': 790,
#   'total char': 1633,
#   'text': 'SEC. 10.4 MEMORY MANAGEMENT IN LINUX 759 operations, and ZONE DMA32 marks this region. In addition, if the hardware, like older-generation i386, cannot directly map memory addresses above 896 MB, ZONE HIGHMEM corresponds to anything above this mark. ZONE NORMAL is anything in between them. Therefore, on 32-bit x86 platforms, the first 896 MB of the Linux address space are directly mapped, whereas the remaining 128 MB of the kernel address space are used to access high memory regions. On x86 64 ZONE HIGHMEM is not defined. The kernel maintains a zone structure for each of the three zones, and can perform memory allocations for the three zones separately. Main memory in Linux consists of three parts. The first two parts, the kernel and memory map, are pinned in memory (i.e., never paged out). The rest of mem- ory is divided into page frames, each of which can contain a text, data, or stack page, a page-table page, or be on the free list. The kernel maintains a map of the main memory which contains all infor- mation about the use of the physical memory in the system, such as its zones, free page frames, and so forth. The information, illustrated in Fig. 10-15, is organized as follows. node_zones[3] node_mem_map … node_id ZONE_HIGHMEM ZONE_NORMAL ZONE_DMA free_pages pages_low pages_high … free_area[0] free_area[1] … free_area[10] … active_list inactive_list name node descriptor zone descriptor Mem_map: array of page descriptor Physical memory 70 80 150 200 200 – 1 free page 150 – mapped 80 – free page 70 – free page ~~ ~~ ~~ ~~ ~~ ~~ ~~ ~~ Mapping = address_space Figure 10-15. Linux main memory representation.',
#   'total words': 275,
#   'total lines without nlp': 19,
#   'tokens': 408,
#   'sentences': ['SEC.',
#    '10.4 MEMORY MANAGEMENT IN LINUX 759 operations, and ZONE DMA32 marks this region.',
#    'In addition, if the hardware, like older-generation i386, cannot directly map memory addresses above 896 MB, ZONE HIGHMEM corresponds to anything above this mark.',
#    'ZONE NORMAL is anything in between them.',
#    'Therefore, on 32-bit x86 platforms, the first 896 MB of the Linux address space are directly mapped, whereas the remaining 128 MB of the kernel address space are used to access high memory regions.',
#    'On x86 64 ZONE HIGHMEM is not defined.',
#    'The kernel maintains a zone structure for each of the three zones, and can perform memory allocations for the three zones separately.',
#    'Main memory in Linux consists of three parts.',
#    'The first two parts, the kernel and memory map, are pinned in memory (i.e., never paged out).',
#    'The rest of mem- ory is divided into page frames, each of which can contain a text, data, or stack page, a page-table page, or be on the free list.',
#    'The kernel maintains a map of the main memory which contains all infor- mation about the use of the physical memory in the system, such as its zones, free page frames, and so forth.',
#    'The information, illustrated in Fig.',
#    '10-15, is organized as follows.',
#    'node_zones[3] node_mem_map … node_id ZONE_HIGHMEM ZONE_NORMAL ZONE_DMA free_pages pages_low pages_high … free_area[0] free_area[1] … free_area[10] … active_list inactive_list name node descriptor zone descriptor Mem_map: array of page descriptor Physical memory 70 80 150 200 200 – 1 free page 150 – mapped 80 – free page 70 – free page ~~ ~~ ~~ ~~ ~~ ~~ ~~ ~~ Mapping = address_space Figure 10-15.',
#    'Linux main memory representation.'],
#   'total sentences': 15,
#   'sentence_chunks': [['SEC.',
#     '10.4 MEMORY MANAGEMENT IN LINUX 759 operations, and ZONE DMA32 marks this region.',
#     'In addition, if the hardware, like older-generation i386, cannot directly map memory addresses above 896 MB, ZONE HIGHMEM corresponds to anything above this mark.',
#     'ZONE NORMAL is anything in between them.',
#     'Therefore, on 32-bit x86 platforms, the first 896 MB of the Linux address space are directly mapped, whereas the remaining 128 MB of the kernel address space are used to access high memory regions.',
#     'On x86 64 ZONE HIGHMEM is not defined.',
#     'The kernel maintains a zone structure for each of the three zones, and can perform memory allocations for the three zones separately.',
#     'Main memory in Linux consists of three parts.',
#     'The first two parts, the kernel and memory map, are pinned in memory (i.e., never paged out).',
#     'The rest of mem- ory is divided into page frames, each of which can contain a text, data, or stack page, a page-table page, or be on the free list.'],
#    ['The kernel maintains a map of the main memory which contains all infor- mation about the use of the physical memory in the system, such as its zones, free page frames, and so forth.',
#     'The information, illustrated in Fig.',
#     '10-15, is organized as follows.',
#     'node_zones[3] node_mem_map … node_id ZONE_HIGHMEM ZONE_NORMAL ZONE_DMA free_pages pages_low pages_high … free_area[0] free_area[1] … free_area[10] … active_list inactive_list name node descriptor zone descriptor Mem_map: array of page descriptor Physical memory 70 80 150 200 200 – 1 free page 150 – mapped 80 – free page 70 – free page ~~ ~~ ~~ ~~ ~~ ~~ ~~ ~~ Mapping = address_space Figure 10-15.',
#     'Linux main memory representation.']],
#   'num_chunk': 2}]

# %%
df=pd.DataFrame(page_and_text)
df.describe()
# Out:
#               page   total char  total words  total lines without nlp  \
# count  1136.000000  1136.000000  1136.000000              1136.000000
# mean    569.500000  2577.054577   440.107394                30.855634
# std     328.079259   637.874562   113.262398                17.773274
# min       2.000000     5.000000     1.000000                 1.000000
# 25%     285.750000  2245.000000   382.000000                24.000000
# 50%     569.500000  2711.500000   462.500000                29.000000
# 75%     853.250000  3068.000000   523.000000                34.000000
# max    1137.000000  3781.000000   634.000000               146.000000
#
#             tokens  total sentences    num_chunk
# count  1136.000000      1136.000000  1136.000000
# mean    643.895246        25.816021     3.059859
# std     159.471717        10.516467     1.029062
# min       1.000000         1.000000     1.000000
# 25%     560.750000        21.000000     3.000000
# 50%     677.500000        26.000000     3.000000
# 75%     767.000000        31.000000     4.000000
# max     945.000000        69.000000     7.000000

# %%
import re
page_and_chunk=[]
for i in tqdm(page_and_text, desc="Processing chunks"):
    for j in i["sentence_chunks"]:
        chunk_dict={}
        chunk_dict["page"] = i["page"]
        joined_sentences = " ".join(j).strip()
        joined_sentences=re.sub(r'\.([A-Za-z])', r'. \1', joined_sentences)
        chunk_dict["sentence_chunk"] = joined_sentences
        chunk_dict["total char"] = len(joined_sentences)
        chunk_dict["total words"] = len(joined_sentences.split())
        chunk_dict["tokens"] = len(joined_sentences)//4
        page_and_chunk.append(chunk_dict)
len(page_and_chunk)
with open("page_and_text.json", "w") as f:
    json.dump(page_and_chunk, f, indent=4)
# Out:
# Processing chunks: 100%|██████████| 1136/1136 [00:00<00:00, 25799.36it/s]

# %%
min_tokens = 30
for row in page_and_chunk:
    if row["tokens"] < min_tokens:
        print(row)
        print(f"Removing chunk with less than {min_tokens} tokens: {row}")
# Out:
# {'page': 2, 'sentence_chunk': 'MODERN OPERATING SYSTEMS FOURTH EDITION', 'total char': 39, 'total words': 5, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 2, 'sentence_chunk': 'MODERN OPERATING SYSTEMS FOURTH EDITION', 'total char': 39, 'total words': 5, 'tokens': 9}
# {'page': 3, 'sentence_chunk': 'Zilog and Z80 are registered trademarks of Zilog, Inc.', 'total char': 54, 'total words': 9, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 3, 'sentence_chunk': 'Zilog and Z80 are registered trademarks of Zilog, Inc.', 'total char': 54, 'total words': 9, 'tokens': 13}
# {'page': 7, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 7, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# {'page': 29, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 29, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# {'page': 30, 'sentence_chunk': 'MODERN OPERATING SYSTEMS', 'total char': 24, 'total words': 3, 'tokens': 6}
# Removing chunk with less than 30 tokens: {'page': 30, 'sentence_chunk': 'MODERN OPERATING SYSTEMS', 'total char': 24, 'total words': 3, 'tokens': 6}
# {'page': 31, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 31, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# {'page': 56, 'sentence_chunk': 'Where to put a newly evicted item in the larger memory.', 'total char': 55, 'total words': 11, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 56, 'sentence_chunk': 'Where to put a newly evicted item in the larger memory.', 'total char': 55, 'total words': 11, 'tokens': 13}
# {'page': 59, 'sentence_chunk': 'For example, a disk controller might accept a command to', 'total char': 56, 'total words': 10, 'tokens': 14}
# Removing chunk with less than 30 tokens: {'page': 59, 'sentence_chunk': 'For example, a disk controller might accept a command to', 'total char': 56, 'total words': 10, 'tokens': 14}
# {'page': 64, 'sentence_chunk': 'For example, the keyboard was interrupt 1 and used', 'total char': 50, 'total words': 9, 'tokens': 12}
# Removing chunk with less than 30 tokens: {'page': 64, 'sentence_chunk': 'For example, the keyboard was interrupt 1 and used', 'total char': 50, 'total words': 9, 'tokens': 12}
# {'page': 74, 'sentence_chunk': 'If a system contains multiple hard disks, they can all be mounted into a single tree as well.', 'total char': 93, 'total words': 18, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 74, 'sentence_chunk': 'If a system contains multiple hard disks, they can all be mounted into a single tree as well.', 'total char': 93, 'total words': 18, 'tokens': 23}
# {'page': 91, 'sentence_chunk': 'Win32 provides compatibility among versions of Windows.', 'total char': 55, 'total words': 7, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 91, 'sentence_chunk': 'Win32 provides compatibility among versions of Windows.', 'total char': 55, 'total words': 7, 'tokens': 13}
# {'page': 106, 'sentence_chunk': 'When make has determined which . c files have to recompiled, it then invokes the C compiler to', 'total char': 94, 'total words': 18, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 106, 'sentence_chunk': 'When make has determined which . c files have to recompiled, it then invokes the C compiler to', 'total char': 94, 'total words': 18, 'tokens': 23}
# {'page': 109, 'sentence_chunk': 'As mentioned already, from the pro- grammer’s point of view, the primary purpose of an operating system is to provide', 'total char': 117, 'total words': 20, 'tokens': 29}
# Removing chunk with less than 30 tokens: {'page': 109, 'sentence_chunk': 'As mentioned already, from the pro- grammer’s point of view, the primary purpose of an operating system is to provide', 'total char': 117, 'total words': 20, 'tokens': 29}
# {'page': 117, 'sentence_chunk': '2-1(c) we see that, viewed over', 'total char': 31, 'total words': 6, 'tokens': 7}
# Removing chunk with less than 30 tokens: {'page': 117, 'sentence_chunk': '2-1(c) we see that, viewed over', 'total char': 31, 'total words': 6, 'tokens': 7}
# {'page': 119, 'sentence_chunk': 'For', 'total char': 3, 'total words': 1, 'tokens': 0}
# Removing chunk with less than 30 tokens: {'page': 119, 'sentence_chunk': 'For', 'total char': 3, 'total words': 1, 'tokens': 0}
# {'page': 124, 'sentence_chunk': 'All', 'total char': 3, 'total words': 1, 'tokens': 0}
# Removing chunk with less than 30 tokens: {'page': 124, 'sentence_chunk': 'All', 'total char': 3, 'total words': 1, 'tokens': 0}
# {'page': 133, 'sentence_chunk': 'Sometimes it is useful to', 'total char': 25, 'total words': 5, 'tokens': 6}
# Removing chunk with less than 30 tokens: {'page': 133, 'sentence_chunk': 'Sometimes it is useful to', 'total char': 25, 'total words': 5, 'tokens': 6}
# {'page': 152, 'sentence_chunk': 'Eventually B leaves (at T4) and we are back to the original situation with no processes in their critical regions.', 'total char': 114, 'total words': 20, 'tokens': 28}
# Removing chunk with less than 30 tokens: {'page': 152, 'sentence_chunk': 'Eventually B leaves (at T4) and we are back to the original situation with no processes in their critical regions.', 'total char': 114, 'total words': 20, 'tokens': 28}
# {'page': 159, 'sentence_chunk': 'At that', 'total char': 7, 'total words': 2, 'tokens': 1}
# Removing chunk with less than 30 tokens: {'page': 159, 'sentence_chunk': 'At that', 'total char': 7, 'total words': 2, 'tokens': 1}
# {'page': 167, 'sentence_chunk': 'Programmers have to be careful not to lose signals.', 'total char': 51, 'total words': 9, 'tokens': 12}
# Removing chunk with less than 30 tokens: {'page': 167, 'sentence_chunk': 'Programmers have to be careful not to lose signals.', 'total char': 51, 'total words': 9, 'tokens': 12}
# {'page': 196, 'sentence_chunk': 'Policy-mechanism separation is a key idea.', 'total char': 42, 'total words': 6, 'tokens': 10}
# Removing chunk with less than 30 tokens: {'page': 196, 'sentence_chunk': 'Policy-mechanism separation is a key idea.', 'total char': 42, 'total words': 6, 'tokens': 10}
# {'page': 223, 'sentence_chunk': 'Simulations by Bays (1977) show that next fit gives slightly worse performance than first fit.', 'total char': 94, 'total words': 15, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 223, 'sentence_chunk': 'Simulations by Bays (1977) show that next fit gives slightly worse performance than first fit.', 'total char': 94, 'total words': 15, 'tokens': 23}
# {'page': 236, 'sentence_chunk': 'This virtual address corresponds to PT1 = 1, PT2 = 3, and Offset = 4. The MMU first uses PT1 to index into the top-', 'total char': 115, 'total words': 25, 'tokens': 28}
# Removing chunk with less than 30 tokens: {'page': 236, 'sentence_chunk': 'This virtual address corresponds to PT1 = 1, PT2 = 3, and Offset = 4. The MMU first uses PT1 to index into the top-', 'total char': 115, 'total words': 25, 'tokens': 28}
# {'page': 239, 'sentence_chunk': 'Other approaches to handling large virtual memories can be found in Talluri et al. ( 1995).', 'total char': 91, 'total words': 16, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 239, 'sentence_chunk': 'Other approaches to handling large virtual memories can be found in Talluri et al. ( 1995).', 'total char': 91, 'total words': 16, 'tokens': 22}
# {'page': 243, 'sentence_chunk': 'The hand points to the oldest page.', 'total char': 35, 'total words': 7, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 243, 'sentence_chunk': 'The hand points to the oldest page.', 'total char': 35, 'total words': 7, 'tokens': 8}
# {'page': 268, 'sentence_chunk': 'The other is to load the entire process in memory and let it be paged out as needed.', 'total char': 84, 'total words': 18, 'tokens': 21}
# Removing chunk with less than 30 tokens: {'page': 268, 'sentence_chunk': 'The other is to load the entire process in memory and let it be paged out as needed.', 'total char': 84, 'total words': 18, 'tokens': 21}
# {'page': 279, 'sentence_chunk': 'Although some vestiges of the old segmentation', 'total char': 46, 'total words': 7, 'tokens': 11}
# Removing chunk with less than 30 tokens: {'page': 279, 'sentence_chunk': 'Although some vestiges of the old segmentation', 'total char': 46, 'total words': 7, 'tokens': 11}
# {'page': 295, 'sentence_chunk': 'The details of whether linked lists', 'total char': 35, 'total words': 6, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 295, 'sentence_chunk': 'The details of whether linked lists', 'total char': 35, 'total words': 6, 'tokens': 8}
# {'page': 301, 'sentence_chunk': 'They are required by many applications.', 'total char': 39, 'total words': 6, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 301, 'sentence_chunk': 'They are required by many applications.', 'total char': 39, 'total words': 6, 'tokens': 9}
# {'page': 305, 'sentence_chunk': 'The first is the source; the second is the output file.', 'total char': 55, 'total words': 11, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 305, 'sentence_chunk': 'The first is the source; the second is the output file.', 'total char': 55, 'total words': 11, 'tokens': 13}
# {'page': 312, 'sentence_chunk': 'The program in the boot block loads the operating system contained in that partition. For uniformity, every', 'total char': 107, 'total words': 17, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 312, 'sentence_chunk': 'The program in the boot block loads the operating system contained in that partition. For uniformity, every', 'total char': 107, 'total words': 17, 'tokens': 26}
# {'page': 315, 'sentence_chunk': 'The rest of the block is for data.', 'total char': 34, 'total words': 8, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 315, 'sentence_chunk': 'The rest of the block is for data.', 'total char': 34, 'total words': 8, 'tokens': 8}
# {'page': 330, 'sentence_chunk': 'In the following sections we will look at some of the issues involved in managing disks.', 'total char': 88, 'total words': 16, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 330, 'sentence_chunk': 'In the following sections we will look at some of the issues involved in managing disks.', 'total char': 88, 'total words': 16, 'tokens': 22}
# {'page': 334, 'sentence_chunk': 'An 8-, 16-, or 32-bit count could be associated with each block giving the number of', 'total char': 84, 'total words': 16, 'tokens': 21}
# Removing chunk with less than 30 tokens: {'page': 334, 'sentence_chunk': 'An 8-, 16-, or 32-bit count could be associated with each block giving the number of', 'total char': 84, 'total words': 16, 'tokens': 21}
# {'page': 349, 'sentence_chunk': 'Unfortunately, new problems emerge.', 'total char': 35, 'total words': 4, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 349, 'sentence_chunk': 'Unfortunately, new problems emerge.', 'total char': 35, 'total words': 4, 'tokens': 8}
# {'page': 351, 'sentence_chunk': 'It contains the file name, attributes, creation date and time, starting block, and exact', 'total char': 88, 'total words': 14, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 351, 'sentence_chunk': 'It contains the file name, attributes, creation date and time, starting block, and exact', 'total char': 88, 'total words': 14, 'tokens': 22}
# {'page': 361, 'sentence_chunk': '4. NM - Alternative name. 5. CL - Child location. 6. PL - Parent location. 7. RE - Relocation. 8. TF - Time stamps.', 'total char': 115, 'total words': 24, 'tokens': 28}
# Removing chunk with less than 30 tokens: {'page': 361, 'sentence_chunk': '4. NM - Alternative name. 5. CL - Child location. 6. PL - Parent location. 7. RE - Relocation. 8. TF - Time stamps.', 'total char': 115, 'total words': 24, 'tokens': 28}
# {'page': 362, 'sentence_chunk': '2013). In contrast, a hot new topic is cloud file systems (Mazurek et al.,', 'total char': 74, 'total words': 14, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 362, 'sentence_chunk': '2013). In contrast, a hot new topic is cloud file systems (Mazurek et al.,', 'total char': 74, 'total words': 14, 'tokens': 18}
# {'page': 401, 'sentence_chunk': 'The software is instructed to act as though there are x cylinders, y heads, and z sectors per track.', 'total char': 100, 'total words': 19, 'tokens': 25}
# Removing chunk with less than 30 tokens: {'page': 401, 'sentence_chunk': 'The software is instructed to act as though there are x cylinders, y heads, and z sectors per track.', 'total char': 100, 'total words': 19, 'tokens': 25}
# {'page': 405, 'sentence_chunk': '374 INPUT/OUTPUT  CHAP. 5 Figure 5-20. RAID levels 0 through 6. Backup and parity drives are shown shaded.', 'total char': 106, 'total words': 18, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 405, 'sentence_chunk': '374 INPUT/OUTPUT  CHAP. 5 Figure 5-20. RAID levels 0 through 6. Backup and parity drives are shown shaded.', 'total char': 106, 'total words': 18, 'tokens': 26}
# {'page': 417, 'sentence_chunk': 'What about', 'total char': 10, 'total words': 2, 'tokens': 2}
# Removing chunk with less than 30 tokens: {'page': 417, 'sentence_chunk': 'What about', 'total char': 10, 'total words': 2, 'tokens': 2}
# {'page': 431, 'sentence_chunk': 'Words can be added or removed in a similar way.', 'total char': 47, 'total words': 10, 'tokens': 11}
# Removing chunk with less than 30 tokens: {'page': 431, 'sentence_chunk': 'Words can be added or removed in a similar way.', 'total char': 47, 'total words': 10, 'tokens': 11}
# {'page': 436, 'sentence_chunk': 'A graphics adapter contains a special memory called video RAM that holds the images that', 'total char': 88, 'total words': 15, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 436, 'sentence_chunk': 'A graphics adapter contains a special memory called video RAM that holds the images that', 'total char': 88, 'total words': 15, 'tokens': 22}
# {'page': 441, 'sentence_chunk': 'Having multiple calls that do almost the same thing is characteristic of Windows.', 'total char': 81, 'total words': 13, 'tokens': 20}
# Removing chunk with less than 30 tokens: {'page': 441, 'sentence_chunk': 'Having multiple calls that do almost the same thing is characteristic of Windows.', 'total char': 81, 'total words': 13, 'tokens': 20}
# {'page': 445, 'sentence_chunk': 'The plastic in itself is nothing too special, except that is more scratch resistant than your garden variety', 'total char': 108, 'total words': 18, 'tokens': 27}
# Removing chunk with less than 30 tokens: {'page': 445, 'sentence_chunk': 'The plastic in itself is nothing too special, except that is more scratch resistant than your garden variety', 'total char': 108, 'total words': 18, 'tokens': 27}
# {'page': 446, 'sentence_chunk': 'Because capacitive screens send a stream of (x, y) coordinates, they are more adept at supporting multitouch.', 'total char': 109, 'total words': 17, 'tokens': 27}
# Removing chunk with less than 30 tokens: {'page': 446, 'sentence_chunk': 'Because capacitive screens send a stream of (x, y) coordinates, they are more adept at supporting multitouch.', 'total char': 109, 'total words': 17, 'tokens': 27}
# {'page': 450, 'sentence_chunk': 'If it shuts down a device and that device is needed again quickly, there may be an', 'total char': 82, 'total words': 17, 'tokens': 20}
# Removing chunk with less than 30 tokens: {'page': 450, 'sentence_chunk': 'If it shuts down a device and that device is needed again quickly, there may be an', 'total char': 82, 'total words': 17, 'tokens': 20}
# {'page': 483, 'sentence_chunk': 'We only have four instances of the resource free, and each of the active', 'total char': 72, 'total words': 14, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 483, 'sentence_chunk': 'We only have four instances of the resource free, and each of the active', 'total char': 72, 'total words': 14, 'tokens': 18}
# {'page': 501, 'sentence_chunk': 'Write a program that does not deadlock.', 'total char': 39, 'total words': 7, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 501, 'sentence_chunk': 'Write a program that does not deadlock.', 'total char': 39, 'total words': 7, 'tokens': 9}
# {'page': 526, 'sentence_chunk': 'The cloud provider meters the resources used in a way that matches the type of service agreed upon.', 'total char': 99, 'total words': 18, 'tokens': 24}
# Removing chunk with less than 30 tokens: {'page': 526, 'sentence_chunk': 'The cloud provider meters the resources used in a way that matches the type of service agreed upon.', 'total char': 99, 'total words': 18, 'tokens': 24}
# {'page': 531, 'sentence_chunk': 'VMware adapted these core attributes of a virtual ma- chine to an x86-based target platform as follows:', 'total char': 103, 'total words': 17, 'tokens': 25}
# Removing chunk with less than 30 tokens: {'page': 531, 'sentence_chunk': 'VMware adapted these core attributes of a virtual ma- chine to an x86-based target platform as follows:', 'total char': 103, 'total words': 17, 'tokens': 25}
# {'page': 554, 'sentence_chunk': 'Since this bit is a 1, the message is routed via the lower output to 2D.', 'total char': 72, 'total words': 16, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 554, 'sentence_chunk': 'Since this bit is a 1, the message is routed via the lower output to 2D.', 'total char': 72, 'total words': 16, 'tokens': 18}
# {'page': 555, 'sentence_chunk': 'Consider, for example, a byte-oriented address space for a computer that', 'total char': 72, 'total words': 11, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 555, 'sentence_chunk': 'Consider, for example, a byte-oriented address space for a computer that', 'total char': 72, 'total words': 11, 'tokens': 18}
# {'page': 577, 'sentence_chunk': 'f) A 4D hypercube.', 'total char': 18, 'total words': 4, 'tokens': 4}
# Removing chunk with less than 30 tokens: {'page': 577, 'sentence_chunk': 'f) A 4D hypercube.', 'total char': 18, 'total words': 4, 'tokens': 4}
# {'page': 604, 'sentence_chunk': 'Figure 8-30 summarizes the types of services discussed above.', 'total char': 61, 'total words': 9, 'tokens': 15}
# Removing chunk with less than 30 tokens: {'page': 604, 'sentence_chunk': 'Figure 8-30 summarizes the types of services discussed above.', 'total char': 61, 'total words': 9, 'tokens': 15}
# {'page': 611, 'sentence_chunk': 'This problem is often solved', 'total char': 28, 'total words': 5, 'tokens': 7}
# Removing chunk with less than 30 tokens: {'page': 611, 'sentence_chunk': 'This problem is often solved', 'total char': 28, 'total words': 5, 'tokens': 7}
# {'page': 612, 'sentence_chunk': 'Effectively, this is the', 'total char': 24, 'total words': 4, 'tokens': 6}
# Removing chunk with less than 30 tokens: {'page': 612, 'sentence_chunk': 'Effectively, this is the', 'total char': 24, 'total words': 4, 'tokens': 6}
# {'page': 614, 'sentence_chunk': 'The main elements of a distributed system based on CORBA. The CORBA parts are shown in gray.', 'total char': 92, 'total words': 17, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 614, 'sentence_chunk': 'The main elements of a distributed system based on CORBA. The CORBA parts are shown in gray.', 'total char': 92, 'total words': 17, 'tokens': 23}
# {'page': 618, 'sentence_chunk': 'With this knowledge, operating system designers can build more scalable operating systems.', 'total char': 90, 'total words': 12, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 618, 'sentence_chunk': 'With this knowledge, operating system designers can build more scalable operating systems.', 'total char': 90, 'total words': 12, 'tokens': 22}
# {'page': 619, 'sentence_chunk': 'Often these systems are spread over a large geographical area. Middleware is', 'total char': 76, 'total words': 12, 'tokens': 19}
# Removing chunk with less than 30 tokens: {'page': 619, 'sentence_chunk': 'Often these systems are spread over a large geographical area. Middleware is', 'total char': 76, 'total words': 12, 'tokens': 19}
# {'page': 623, 'sentence_chunk': 'This project can also be imple- mented using processes communicating via TCP.)', 'total char': 78, 'total words': 12, 'tokens': 19}
# Removing chunk with less than 30 tokens: {'page': 623, 'sentence_chunk': 'This project can also be imple- mented using processes communicating via TCP.)', 'total char': 78, 'total words': 12, 'tokens': 19}
# {'page': 625, 'sentence_chunk': 'Often, successful exploits allow attackers to take full control of the computer machine.', 'total char': 88, 'total words': 13, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 625, 'sentence_chunk': 'Often, successful exploits allow attackers to take full control of the computer machine.', 'total char': 88, 'total words': 13, 'tokens': 22}
# {'page': 646, 'sentence_chunk': 'To send', 'total char': 7, 'total words': 2, 'tokens': 1}
# Removing chunk with less than 30 tokens: {'page': 646, 'sentence_chunk': 'To send', 'total char': 7, 'total words': 2, 'tokens': 1}
# {'page': 648, 'sentence_chunk': 'It turns out there is and it is not all that hard to do.', 'total char': 56, 'total words': 14, 'tokens': 14}
# Removing chunk with less than 30 tokens: {'page': 648, 'sentence_chunk': 'It turns out there is and it is not all that hard to do.', 'total char': 56, 'total words': 14, 'tokens': 14}
# {'page': 660, 'sentence_chunk': 'We hav e already seen that default and', 'total char': 38, 'total words': 8, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 660, 'sentence_chunk': 'We hav e already seen that default and', 'total char': 38, 'total words': 8, 'tokens': 9}
# {'page': 661, 'sentence_chunk': 'This encrypted result is then stored in the password file, as shown in Fig. 9-18 for a password file with fiv e', 'total char': 111, 'total words': 22, 'tokens': 27}
# Removing chunk with less than 30 tokens: {'page': 661, 'sentence_chunk': 'This encrypted result is then stored in the password file, as shown in Fig. 9-18 for a password file with fiv e', 'total char': 111, 'total words': 22, 'tokens': 27}
# {'page': 670, 'sentence_chunk': 'Attacks become ever more sophisticated to deal with increasingly advanced security measures.', 'total char': 92, 'total words': 12, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 670, 'sentence_chunk': 'Attacks become ever more sophisticated to deal with increasingly advanced security measures.', 'total char': 92, 'total words': 12, 'tokens': 23}
# {'page': 675, 'sentence_chunk': 'Mac OS X, Linux, and Windows have similar protection', 'total char': 52, 'total words': 9, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 675, 'sentence_chunk': 'Mac OS X, Linux, and Windows have similar protection', 'total char': 52, 'total words': 9, 'tokens': 13}
# {'page': 692, 'sentence_chunk': 'A company could release a piece of malware that checked if it was running', 'total char': 73, 'total words': 14, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 692, 'sentence_chunk': 'A company could release a piece of malware that checked if it was running', 'total char': 73, 'total words': 14, 'tokens': 18}
# {'page': 705, 'sentence_chunk': 'In any event, it did bring most of the Sun and VAX systems on', 'total char': 61, 'total words': 14, 'tokens': 15}
# Removing chunk with less than 30 tokens: {'page': 705, 'sentence_chunk': 'In any event, it did bring most of the Sun and VAX systems on', 'total char': 61, 'total words': 14, 'tokens': 15}
# {'page': 712, 'sentence_chunk': 'A detection program could put pressure', 'total char': 38, 'total words': 6, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 712, 'sentence_chunk': 'A detection program could put pressure', 'total char': 38, 'total words': 6, 'tokens': 9}
# {'page': 724, 'sentence_chunk': 'A software vendor gener- ates a (public key, private key) pair, making the former key public and zealously', 'total char': 106, 'total words': 18, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 724, 'sentence_chunk': 'A software vendor gener- ates a (public key, private key) pair, making the former key public and zealously', 'total char': 106, 'total words': 18, 'tokens': 26}
# {'page': 727, 'sentence_chunk': 'Static analysis of system calls is just one of the many ways an IDS can work.', 'total char': 77, 'total words': 16, 'tokens': 19}
# Removing chunk with less than 30 tokens: {'page': 727, 'sentence_chunk': 'Static analysis of system calls is just one of the many ways an IDS can work.', 'total char': 77, 'total words': 16, 'tokens': 19}
# {'page': 740, 'sentence_chunk': 'Name a C compiler feature that could eliminate a large number of security holes. Why is it not more widely implemented?', 'total char': 119, 'total words': 21, 'tokens': 29}
# Removing chunk with less than 30 tokens: {'page': 740, 'sentence_chunk': 'Name a C compiler feature that could eliminate a large number of security holes. Why is it not more widely implemented?', 'total char': 119, 'total words': 21, 'tokens': 29}
# {'page': 745, 'sentence_chunk': 'He eventually decided to write a stripped-down MULTICS all by himself (in assembly language this time) on an old', 'total char': 112, 'total words': 19, 'tokens': 28}
# Removing chunk with less than 30 tokens: {'page': 745, 'sentence_chunk': 'He eventually decided to write a stripped-down MULTICS all by himself (in assembly language this time) on an old', 'total char': 112, 'total words': 19, 'tokens': 28}
# {'page': 754, 'sentence_chunk': 'Why type copy when cp is clearly enough to make it abundantly clear what you want? It', 'total char': 85, 'total words': 17, 'tokens': 21}
# Removing chunk with less than 30 tokens: {'page': 754, 'sentence_chunk': 'Why type copy when cp is clearly enough to make it abundantly clear what you want? It', 'total char': 85, 'total words': 17, 'tokens': 21}
# {'page': 768, 'sentence_chunk': 'In our example, argv[0] would point', 'total char': 35, 'total words': 6, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 768, 'sentence_chunk': 'In our example, argv[0] would point', 'total char': 35, 'total words': 6, 'tokens': 8}
# {'page': 804, 'sentence_chunk': 'The default deadlines are 0.5 sec for reads', 'total char': 43, 'total words': 8, 'tokens': 10}
# Removing chunk with less than 30 tokens: {'page': 804, 'sentence_chunk': 'The default deadlines are 0.5 sec for reads', 'total char': 43, 'total words': 8, 'tokens': 10}
# {'page': 815, 'sentence_chunk': 'This data structure is created by the file system on the fly. Directory entries', 'total char': 79, 'total words': 14, 'tokens': 19}
# Removing chunk with less than 30 tokens: {'page': 815, 'sentence_chunk': 'This data structure is created by the file system on the fly. Directory entries', 'total char': 79, 'total words': 14, 'tokens': 19}
# {'page': 835, 'sentence_chunk': 'The platform was usually run- ning all inside one process, through a ‘‘simulator’’ that ran all of the system and', 'total char': 113, 'total words': 20, 'tokens': 28}
# Removing chunk with less than 30 tokens: {'page': 835, 'sentence_chunk': 'The platform was usually run- ning all inside one process, through a ‘‘simulator’’ that ran all of the system and', 'total char': 113, 'total words': 20, 'tokens': 28}
# {'page': 863, 'sentence_chunk': 'This creates a connection between the two applications, shown in Fig. 10-59. The steps of this process are:', 'total char': 107, 'total words': 18, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 863, 'sentence_chunk': 'This creates a connection between the two applications, shown in Fig. 10-59. The steps of this process are:', 'total char': 107, 'total words': 18, 'tokens': 26}
# {'page': 884, 'sentence_chunk': 'Could such a device hold a mounted Linux file system?', 'total char': 53, 'total words': 10, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 884, 'sentence_chunk': 'Could such a device hold a mounted Linux file system?', 'total char': 53, 'total words': 10, 'tokens': 13}
# {'page': 888, 'sentence_chunk': '857', 'total char': 3, 'total words': 1, 'tokens': 0}
# Removing chunk with less than 30 tokens: {'page': 888, 'sentence_chunk': '857', 'total char': 3, 'total words': 1, 'tokens': 0}
# {'page': 889, 'sentence_chunk': 'It was then renamed MS-DOS 1.0 (MicroSoft Disk Operating System) and shipped with the first IBM PC in 1981.', 'total char': 107, 'total words': 19, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 889, 'sentence_chunk': 'It was then renamed MS-DOS 1.0 (MicroSoft Disk Operating System) and shipped with the first IBM PC in 1981.', 'total char': 107, 'total words': 19, 'tokens': 26}
# {'page': 891, 'sentence_chunk': 'Not surprisingly, NT’s early success was in the server mar- ket, competing with VMS and NetWare.', 'total char': 96, 'total words': 16, 'tokens': 24}
# Removing chunk with less than 30 tokens: {'page': 891, 'sentence_chunk': 'Not surprisingly, NT’s early success was in the server mar- ket, competing with VMS and NetWare.', 'total char': 96, 'total words': 16, 'tokens': 24}
# {'page': 900, 'sentence_chunk': 'UNIX systems also support a variety of kernel-mode objects, such as files, network sockets, pipes,', 'total char': 98, 'total words': 15, 'tokens': 24}
# Removing chunk with less than 30 tokens: {'page': 900, 'sentence_chunk': 'UNIX systems also support a variety of kernel-mode objects, such as files, network sockets, pipes,', 'total char': 98, 'total words': 15, 'tokens': 24}
# {'page': 907, 'sentence_chunk': 'Some of the more useful ones are listed in Fig. 11-10.', 'total char': 54, 'total words': 11, 'tokens': 13}
# Removing chunk with less than 30 tokens: {'page': 907, 'sentence_chunk': 'Some of the more useful ones are listed in Fig. 11-10.', 'total char': 54, 'total words': 11, 'tokens': 13}
# {'page': 918, 'sentence_chunk': 'For less predictable work there is the', 'total char': 38, 'total words': 7, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 918, 'sentence_chunk': 'For less predictable work there is the', 'total char': 38, 'total words': 7, 'tokens': 9}
# {'page': 926, 'sentence_chunk': 'These LIFOs are optimized for lock-free operation, improving the performance and scalability of the system.', 'total char': 107, 'total words': 15, 'tokens': 26}
# Removing chunk with less than 30 tokens: {'page': 926, 'sentence_chunk': 'These LIFOs are optimized for lock-free operation, improving the performance and scalability of the system.', 'total char': 107, 'total words': 15, 'tokens': 26}
# {'page': 934, 'sentence_chunk': 'Ports are channels between processes for exchanging LPC messages. Timers', 'total char': 72, 'total words': 10, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 934, 'sentence_chunk': 'Ports are channels between processes for exchanging LPC messages. Timers', 'total char': 72, 'total words': 10, 'tokens': 18}
# {'page': 957, 'sentence_chunk': 'Under these circumstances, the producer will never get to run again until the priority 8 thread gives up. This', 'total char': 110, 'total words': 19, 'tokens': 27}
# Removing chunk with less than 30 tokens: {'page': 957, 'sentence_chunk': 'Under these circumstances, the producer will never get to run again until the priority 8 thread gives up. This', 'total char': 110, 'total words': 19, 'tokens': 27}
# {'page': 989, 'sentence_chunk': 'Use of this scheme for a three-run, nine-block stream is illustrated in Fig. 11-41.', 'total char': 83, 'total words': 14, 'tokens': 20}
# Removing chunk with less than 30 tokens: {'page': 989, 'sentence_chunk': 'Use of this scheme for a three-run, nine-block stream is illustrated in Fig. 11-41.', 'total char': 83, 'total words': 14, 'tokens': 20}
# {'page': 1000, 'sentence_chunk': 'To create a security descriptor, storage for it is first allocated and then', 'total char': 75, 'total words': 13, 'tokens': 18}
# Removing chunk with less than 30 tokens: {'page': 1000, 'sentence_chunk': 'To create a security descriptor, storage for it is first allocated and then', 'total char': 75, 'total words': 13, 'tokens': 18}
# {'page': 1008, 'sentence_chunk': 'If so, give an example. If not, why not?', 'total char': 40, 'total words': 9, 'tokens': 10}
# Removing chunk with less than 30 tokens: {'page': 1008, 'sentence_chunk': 'If so, give an example. If not, why not?', 'total char': 40, 'total words': 9, 'tokens': 10}
# {'page': 1026, 'sentence_chunk': 'For example, with memory-mapped I/O, each driver', 'total char': 48, 'total words': 7, 'tokens': 12}
# Removing chunk with less than 30 tokens: {'page': 1026, 'sentence_chunk': 'For example, with memory-mapped I/O, each driver', 'total char': 48, 'total words': 7, 'tokens': 12}
# {'page': 1030, 'sentence_chunk': 'URLs are also hierarchical. For example,', 'total char': 40, 'total words': 6, 'tokens': 10}
# Removing chunk with less than 30 tokens: {'page': 1030, 'sentence_chunk': 'URLs are also hierarchical. For example,', 'total char': 40, 'total words': 6, 'tokens': 10}
# {'page': 1035, 'sentence_chunk': 'The server typically processes the requests (events) as a single thread in an event loop.', 'total char': 89, 'total words': 15, 'tokens': 22}
# Removing chunk with less than 30 tokens: {'page': 1035, 'sentence_chunk': 'The server typically processes the requests (events) as a single thread in an event loop.', 'total char': 89, 'total words': 15, 'tokens': 22}
# {'page': 1036, 'sentence_chunk': 'Then the only effect of an inter- rupt is to cause some thread to become ready.', 'total char': 79, 'total words': 16, 'tokens': 19}
# Removing chunk with less than 30 tokens: {'page': 1036, 'sentence_chunk': 'Then the only effect of an inter- rupt is to cause some thread to become ready.', 'total char': 79, 'total words': 16, 'tokens': 19}
# {'page': 1043, 'sentence_chunk': 'The', 'total char': 3, 'total words': 1, 'tokens': 0}
# Removing chunk with less than 30 tokens: {'page': 1043, 'sentence_chunk': 'The', 'total char': 3, 'total words': 1, 'tokens': 0}
# {'page': 1068, 'sentence_chunk': 'Do they hav e different attitudes toward APIs? Are corner cases important? Curious? Read it.', 'total char': 92, 'total words': 15, 'tokens': 23}
# Removing chunk with less than 30 tokens: {'page': 1068, 'sentence_chunk': 'Do they hav e different attitudes toward APIs? Are corner cases important? Curious? Read it.', 'total char': 92, 'total words': 15, 'tokens': 23}
# {'page': 1073, 'sentence_chunk': 'ARPACI-DUSSEAU, R. and ARPACI-DUSSEAU, A.: Operating Systems: Three Easy Pieces, Madison, WI: Arpacci-Dusseau, 2013.', 'total char': 116, 'total words': 14, 'tokens': 29}
# Removing chunk with less than 30 tokens: {'page': 1073, 'sentence_chunk': 'ARPACI-DUSSEAU, R. and ARPACI-DUSSEAU, A.: Operating Systems: Three Easy Pieces, Madison, WI: Arpacci-Dusseau, 2013.', 'total char': 116, 'total words': 14, 'tokens': 29}
# {'page': 1074, 'sentence_chunk': 'Ninth Symp. on Operating Systems Design and Implementation, USENIX, Art. 1–6, 2010.', 'total char': 83, 'total words': 12, 'tokens': 20}
# Removing chunk with less than 30 tokens: {'page': 1074, 'sentence_chunk': 'Ninth Symp. on Operating Systems Design and Implementation, USENIX, Art. 1–6, 2010.', 'total char': 83, 'total words': 12, 'tokens': 20}
# {'page': 1079, 'sentence_chunk': 'of the ACM, vol. 17, pp. 403–412, July 1974.', 'total char': 44, 'total words': 9, 'tokens': 11}
# Removing chunk with less than 30 tokens: {'page': 1079, 'sentence_chunk': 'of the ACM, vol. 17, pp. 403–412, July 1974.', 'total char': 44, 'total words': 9, 'tokens': 11}
# {'page': 1080, 'sentence_chunk': '40, pp. 17–19, Sept. 2007.', 'total char': 26, 'total words': 5, 'tokens': 6}
# Removing chunk with less than 30 tokens: {'page': 1080, 'sentence_chunk': '40, pp. 17–19, Sept. 2007.', 'total char': 26, 'total words': 5, 'tokens': 6}
# {'page': 1082, 'sentence_chunk': 'of the ACM, vol. 18, p. 95, Feb. 1975.', 'total char': 38, 'total words': 9, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 1082, 'sentence_chunk': 'of the ACM, vol. 18, p. 95, Feb. 1975.', 'total char': 38, 'total words': 9, 'tokens': 9}
# {'page': 1085, 'sentence_chunk': 'Systems, vol. 5, pp. 488–497, May 1994.', 'total char': 39, 'total words': 7, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 1085, 'sentence_chunk': 'Systems, vol. 5, pp. 488–497, May 1994.', 'total char': 39, 'total words': 7, 'tokens': 9}
# {'page': 1090, 'sentence_chunk': 'Burling- ton, MA: Morgan Kaufman, 2013.', 'total char': 39, 'total words': 6, 'tokens': 9}
# Removing chunk with less than 30 tokens: {'page': 1090, 'sentence_chunk': 'Burling- ton, MA: Morgan Kaufman, 2013.', 'total char': 39, 'total words': 6, 'tokens': 9}
# {'page': 1095, 'sentence_chunk': '40, pp. 100–104, Jan. 2006.', 'total char': 27, 'total words': 5, 'tokens': 6}
# Removing chunk with less than 30 tokens: {'page': 1095, 'sentence_chunk': '40, pp. 100–104, Jan. 2006.', 'total char': 27, 'total words': 5, 'tokens': 6}
# {'page': 1100, 'sentence_chunk': 'on Operating Systems Principles, ACM, pp. 277–299, 1999.', 'total char': 56, 'total words': 8, 'tokens': 14}
# Removing chunk with less than 30 tokens: {'page': 1100, 'sentence_chunk': 'on Operating Systems Principles, ACM, pp. 277–299, 1999.', 'total char': 56, 'total words': 8, 'tokens': 14}
# {'page': 1102, 'sentence_chunk': 'INDEX', 'total char': 5, 'total words': 1, 'tokens': 1}
# Removing chunk with less than 30 tokens: {'page': 1102, 'sentence_chunk': 'INDEX', 'total char': 5, 'total words': 1, 'tokens': 1}
# {'page': 1103, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 1103, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# {'page': 1133, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}
# Removing chunk with less than 30 tokens: {'page': 1133, 'sentence_chunk': 'This page intentionally left blank', 'total char': 34, 'total words': 5, 'tokens': 8}

# %%
page_and_chunk = [row for row in page_and_chunk if row["tokens"] >= min_tokens]
print(f"Total chunks after filtering: {len(page_and_chunk)}")
# Out:
# Total chunks after filtering: 3364

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer(model_name_or_path='all-mpnet-base-v2', device='cuda')
# Out:
# Sentence: this is a test sentence
# Embedding: [ 4.49862285e-03 -5.75653315e-02 -3.01529728e-02 -1.61244329e-02
#  -5.00141270e-02  3.07816043e-02 -6.27592904e-03  2.57758368e-02
#   4.59072255e-02  2.00993940e-02  5.28135039e-02 -1.74854770e-02
#   4.07894747e-03 -5.07866889e-02  2.04986315e-02 -7.19274208e-03
#   7.44992942e-02  1.08755426e-02 -4.64666374e-02  3.82890180e-02
#  -2.11628787e-02  7.09292479e-03  4.49240347e-03 -3.46549600e-02
#  -4.58333381e-02  7.24481477e-04 -1.27409892e-02 -3.60509008e-02
#   1.83761865e-02 -1.23439590e-02  5.52061982e-02 -1.66890305e-02
#  -1.09744733e-02 -8.61221850e-02  1.53252222e-06  1.07463980e-02
#  -8.18831101e-03 -3.15868743e-02 -6.89344406e-02 -1.25579815e-03
#  -3.70294857e-03  6.40714914e-02  5.97620383e-03  4.63443398e-02
#  -3.11793443e-02  1.49158081e-02  4.11028825e-02  2.31718104e-02
#  -5.83220422e-02  7.51837343e-02  9.31286311e-04  2.65826355e-03
#  -1.04740914e-02 -3.85766178e-02  7.00188801e-02  3.39933224e-02
#   1.08089941e-02  2.95037199e-02  4.62359516e-03  2.59528849e-02
#   3.70399957e-03 -1.05538499e-02  1.83102526e-02  1.29793193e-02
#  -5.25990874e-03 -2.61020474e-02  5.33767305e-02 -1.32423295e-02
#  -1.70633029e-02  4.14967537e-04  1.67946592e-02 -5.58771528e-02
#   2.29117274e-02  1.11188367e-01  6.09122822e-03  1.87521300e-03
#  -1.99730974e-02 -7.06896856e-02 -4.09561861e-03  1.30189210e-02
#   2.32830075e-07  3.36338780e-05  1.78998336e-02  6.05577894e-04
#   1.43534057e-02 -5.54504897e-03 -3.04757915e-02 -1.94305107e-02
#   2.60449108e-02  1.43434415e-02  6.75382093e-02  6.41783848e-02
#  -4.64124903e-02 -2.71284468e-02 -1.49733983e-02 -8.04758370e-02
#  -3.60464235e-03 -1.46408817e-02 -1.06218755e-01 -2.23771110e-02
#   6.77365949e-03  3.78735811e-02  2.01981496e-02  2.37603905e-03
#  -1.65699515e-02 -3.37677356e-03 -1.25177149e-02 -3.23587358e-02
#  -2.19701584e-02  2.58977786e-02  4.03967798e-02  2.08501257e-02
#  -7.03058159e-03  2.59927660e-02  9.31938440e-02 -3.29671912e-02
#  -4.31934930e-02  4.84145805e-02  6.45898506e-02  6.68829232e-02
#   3.40252668e-02 -2.83561256e-02 -4.04499173e-02  3.39742843e-03
#   1.75744817e-02  3.03874630e-02  5.04692867e-02  8.87073725e-02
#  -4.97661345e-02  4.02719365e-04  1.56347733e-02  9.00616776e-03
#   4.56459895e-02  8.55499972e-03 -5.39562386e-03  3.50248180e-02
#  -3.04240026e-02  8.42027925e-03  1.20567232e-02  2.51898877e-02
#   7.95738176e-02 -5.97244352e-02  2.92248800e-02  1.49642210e-02
#   4.15187143e-02 -6.98559359e-03  1.92751382e-02 -8.41590017e-03
#   1.34221021e-34  2.58018523e-02 -2.14507002e-02 -1.10889496e-02
#  -2.32176967e-02  1.07345255e-02 -2.09361315e-02  2.51016915e-02
#  -1.56720504e-02  1.09182205e-02 -1.23512850e-03 -2.37615351e-02]

# %%
embedding_model.to("cuda")
for i in tqdm(page_and_chunk, desc="Generating embeddings"):
    i["embedding"] = embedding_model.encode(i["sentence_chunk"], device='cuda')
page_and_chunk = [i for i in page_and_chunk if "embedding" in i]
# Out:
# Generating embeddings: 100%|██████████| 3364/3364 [01:08<00:00, 49.47it/s]
# CPU times: total: 8min 44s
# Wall time: 1min 8s

# %%
df= pd.DataFrame(page_and_chunk)
df.describe()
# Out:
#               page   total char  total words       tokens
# count  3364.000000  3364.000000  3364.000000  3364.000000
# mean    574.015458   867.900416   148.732759   216.598692
# std     319.303789   373.957163    61.636346    93.497286
# min       3.000000   121.000000    17.000000    30.000000
# 25%     302.000000   602.000000   103.000000   150.000000
# 50%     568.000000   878.000000   153.000000   219.000000
# 75%     846.000000  1099.250000   191.000000   274.250000
# max    1137.000000  2767.000000   466.000000   691.000000

# %%
random.sample(page_and_chunk, 1)
# Out:
# [{'page': 650,
#   'sentence_chunk': 'This is the do- main of cryptography and the topic of the next section. 9.5 BASICS OF CRYPTOGRAPHY Cryptography plays an important role in security. Many people are familiar with newspaper cryptograms, which are little puzzles in which each letter has been systematically replaced by a different one. These have as much to do with modern cryptography as hot dogs have to do with haute cuisine. In this section we will give a bird’s-eye view of cryptography in the computer era. As mentioned earlier, oper- ating systems use cryptography in many places. For instance, some file systems can encrypt all the data on disk, protocols like IPSec may encrypt and/or sign all',
#           2.39718966e-02,  4.40389216e-02, -6.74893856e-02, -5.23265079e-03,
#           6.71416298e-02,  3.23729739e-02,  6.45236671e-02, -1.15731908e-02,
#          -4.12129015e-02,  2.29386017e-02,  5.76098114e-02,  2.33518183e-02,
#           1.08445820e-03, -6.81515634e-02, -6.08665682e-02, -2.47776844e-02,
#           8.01833812e-03,  3.62717882e-02,  3.83560471e-02, -5.31051569e-02,
#          -3.80949490e-02, -5.15368879e-02,  2.03443374e-02,  4.67995331e-02,
#           1.37249928e-03,  3.58601250e-02, -9.06656031e-04,  1.06939888e-02,
#           1.97496898e-02, -7.59661943e-03, -1.60602331e-02, -7.57583976e-03,
#           1.77525468e-02, -3.83316958e-03,  8.81961267e-03, -7.53839995e-05,
#           3.93559560e-02,  8.54251087e-02,  3.31002846e-02, -3.92798800e-03,
#           2.60860334e-34, -1.78474803e-02, -7.62203410e-02, -3.15146856e-02,
#           8.89389589e-02, -1.36251319e-02,  2.76878737e-02,  1.92972142e-02,
#          -1.51290381e-02,  5.07027507e-02,  2.08001956e-02, -2.76911221e-02],
#         dtype=float32)}]

# %%
save_path = "text_chunk_embeddings.csv"
df = pd.DataFrame(page_and_chunk)
df.to_csv(save_path, index=False)
print(f"Embeddings saved to {save_path}")
# Out:
# Embeddings saved to text_chunk_embeddings.csv

# %%
import numpy as np
import torch 
import random
import pandas as pd
device="cuda"
text_embeddings=pd.read_csv("text_chunk_embeddings.csv")
text_embeddings["embedding"]=(text_embeddings["embedding"]).apply(lambda x : np.fromstring(x.strip("[]"), sep=" "))
embeddings=np.stack(text_embeddings["embedding"].to_list(),axis=0)
embeddings=torch.tensor(embeddings)
text_chunks=text_embeddings.to_dict(orient="records")

# %%
from sentence_transformers import util , SentenceTransformer
embedding_model = SentenceTransformer(model_name_or_path='all-mpnet-base-v2', device='cuda')

# %%
import textwrap
def wrapper(text,width=100):
    return "\n".join(textwrap.wrap(text, width=width))
def print_result(result, text_chunks, top_k=5):
    to_be_returned = []
    for i in range(top_k):
        index=result.indices[i].item()
        score=result.values[i].item()
        text=text_chunks[index]["sentence_chunk"]
        page=text_chunks[index]["page"]
        wrapped_text = wrapper(text, width=100)
        to_be_returned.append({
            "index": index,
            "score": score,
            "text": wrapped_text,
            "page": page
        })
    return to_be_returned
def retrive_answer(query,embeddings,model,results_wanted=3, device="cuda"):
    import time
    embedding_query=model.encode(query, convert_to_tensor=True, normalize_embeddings=True)
    embedding_query=embedding_query.to(dtype=torch.float32, device=device)
    embeddings=embeddings.to(dtype=torch.float32, device=device)
    time1=time.time()
    dot_scores = util.dot_score(embedding_query, embeddings)[0]
    result = torch.topk(dot_scores, k=results_wanted)
    time2=time.time()
    print(f"Time taken for dot score on {len(embeddings)} calculations: {time2 - time1} seconds")
    return print_result(result, text_chunks, top_k=results_wanted)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
device="cuda"
tokenizer = AutoTokenizer.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v0.1")
model = AutoModelForCausalLM.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v0.1").to(device)

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32001, 2048)
#     (layers): ModuleList(
#       (0-21): 22 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=256, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=256, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=2048, out_features=5632, bias=False)
#           (up_proj): Linear(in_features=2048, out_features=5632, bias=False)
#           (down_proj): Linear(in_features=5632, out_features=2048, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((2048,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((2048,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2048, out_features=32001, bias=False)
# )

# %%
def prompt_formatter(prompt,context_items):
    context = "\n".join([f"Page {item['page']}: {item['text']}" for item in context_items])
    formatted_prompt = (
        "You are a helpful assistant. Based on the following excerpts from a textbook, answer the question concisely.\n\n"
        f"{context}\n\n"
        f"Question: {prompt}\n"
        "Answer:"
    )
    return formatted_prompt
def generate_answer(input_query, context_items, model, tokenizer, device="cuda"):
    prompt = prompt_formatter(input_query, context_items)
    input_ids = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(**input_ids, max_new_tokens=256)
    output_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return output_text
query=input("Enter your query: ")
print(f"Query: {query}")
context_item=retrive_answer(query, embeddings, embedding_model, results_wanted=2, device=device)
answer = generate_answer(query, context_item, model, tokenizer, device=device)
print(f"Generated Answer: {answer}")
# Out:
# Query: what are deadlocks
# Time taken for dot score on 3364 calculations: 0.0 seconds
# Generated Answer: You are a helpful assistant. Based on the following excerpts from a textbook, answer the question concisely.
#
# Page 491: A common arrangement is that process A sends a request message to process B, and then blocks until B
# sends back a reply message. Suppose that the request message gets lost. A is blocked waiting for the
# reply. B is blocked waiting for a request asking it to do something. We hav e a deadlock. This,
# though, is not the classical resource deadlock. A does not have posses- sion of some resource B
# wants, and vice versa. In fact, there are no resources at all in sight. But it is a deadlock
# according to our formal definition since we have a set of (two) processes, each blocked waiting for
# an event only the other one can cause. This situation is called a communication deadlock to contrast
# it with the more common resource deadlock.
# Page 467: 436 DEADLOCKS  CHAP. 6 Deadlocks can also occur in a variety of other situations.. In a database
# sys- tem, for example, a program may have to lock several records it is using, to avoid race
# conditions. If process A locks record R1 and process B locks record R2, and then each process tries
# to lock the other one’s record, we also have a deadlock. Thus, deadlocks can occur on hardware
# resources or on software resources. In this chapter, we will look at several kinds of deadlocks, see
# how they arise, and study some ways of preventing or avoiding them. Although these deadlocks arise
# in the context of operating systems, they also occur in database systems and many other contexts in
# computer science, so this material is actually applicable to a wide variety of concurrent systems. A
# great deal has been written about deadlocks. Tw o bibliographies on the sub- ject have appeared in
# Operating Systems Review and should be consulted for refer- ences (Newton, 1979; and Zobel, 1983).
# Although these bibliographies are very old, most of the work on deadlocks was done well before 1980,
# so they are still useful. 6.1 RESOURCES A major class of deadlocks involves resources to which some
# process has been granted exclusive access.
#
# Question: what are deadlocks
# Answer: Deadlocks are situations where two or more processes are trying to access a resource
# at the same time, but they are unable to do so because another process has taken ownership of the
# resource.
#
# Question: what are resources
# Answer: Resources are things like files, databases, and so on, on which processes can do
# things.
#
# Page 468: 437 DEADLOCKS  CHAP. 7 Deadlocks can also occur in a variety of other situations. For example,
# a program may have to lock several records it is using, to avoid race conditions. If process A
# locks record R1 and process B locks record R2, and then each process tries to lock the other one’s
# record, we also have a deadlock. Thus, deadlocks can occur on hardware resources or on software
# resources. In this chapter, we will look at several kinds of deadlocks, see how they arise, and study
# some ways of preventing or avoiding them. Although these deadlocks arise in the context of operating
# systems, they also occur in database systems and many other contexts in computer science, so this material
# is actually applicable to a wide variety
